# %%
# Colab: initial install (run once)

# !pip install --upgrade pip
# !pip install --quiet google-genai

# Verify installation
import pkgutil
print("google-genai installed:", pkgutil.find_loader("google") is not None)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 17.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# google-genai installed: True
# /tmp/ipykernel_271/2403294772.py:8: DeprecationWarning: 'pkgutil.find_loader' is deprecated and slated for removal in Python 3.14; use importlib.util.find_spec() instead
#   print("google-genai installed:", pkgutil.find_loader("google") is not None)

# %%
from google import genai

# %%
from google import genai

API_KEY = "AIzaSyBGddcnx5LUXDTIMW_ZHjp7fmxhE_J2R6A"

# Initialize client with API key
client = genai.Client(api_key=API_KEY)

print("Gemini API configured successfully")
# Out:
# Gemini API configured successfully

# %%
prompt = """
Explain Generative Adversarial Networks (GANs)
and describe the generator and discriminator roles.
"""

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=prompt
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_271/783774036.py in <cell line: 0>()
#       4 """
#       5
# ----> 6 response = client.models.generate_content(
#       7     model="gemini-2.0-flash",
#       8     contents=prompt
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5642     while remaining_remote_calls_afc > 0:
#    5643       i += 1
# -> 5644       response = self._generate_content(
#    5645           model=model, contents=contents, config=parsed_config
#    5646       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4304     request_dict = _common.encode_unserializable_types(request_dict)
#    4305
# -> 4306     response = self._api_client.request(
# ...
